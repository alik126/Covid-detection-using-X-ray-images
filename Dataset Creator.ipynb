# %%
import pandas as pd
import os 
import shutil

# %%
file_path = "metadata.csv"
images_path = "chest_xray/train/PNEUMONIA"

# %%
df = pd.read_csv(file_path)
print(df.shape)
# Out:
# (950, 30)

# %%
df.head()
# Out:
#   patientid  offset sex   age finding RT_PCR_positive survival intubated  \
# 0         2     0.0   M  65.0  COVID                Y        Y         N
# 1         2     3.0   M  65.0   COVID               Y        Y         N
# 2         2     5.0   M  65.0   COVID               Y        Y         N
# 3         2     6.0   M  65.0   COVID               Y        Y         N
# 4         4     0.0   F  52.0   COVID               Y      NaN         N
#
#   intubation_present went_icu  ...       date  \
# 0                  N        N  ...  22-Jan-20
# 1                  N        N  ...  25-Jan-20
# 2                  N        N  ...  27-Jan-20
# 3                  N        N  ...  28-Jan-20
# 4                  N        N  ...  25-Jan-20
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# ...

# %%
target_dir = "Dataset/Covid"
